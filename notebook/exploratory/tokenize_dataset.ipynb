# %%
import spacy
import sys
import os

# %%
# load dataset 
script_abs_path = '/home/sasatake/repos/python/transformer/script'
sys.path.append(script_abs_path)

import load_dataset
multi30 = load_dataset.Multi30k()

# %%
# the trial for tokenize of English
nlp_de = spacy.load('de_core_news_sm')
for text in multi30.datasets['texts_src_de_train'][:5]:
    print('-----------------------------------')
    print(text)
    doc = nlp_de(text)
    for token in doc:
        print(token.text, token.pos_, token.dep_)
# Out:
# -----------------------------------
# Zwei junge weiße Männer sind im Freien in der Nähe vieler Büsche.
#
# Zwei NUM nk
# junge ADJ nk
# weiße ADJ nk
# Männer NOUN sb
# sind AUX ROOT
# im ADP mo
# Freien NOUN nk
# in ADP mo
# der DET nk
# Nähe NOUN nk
# vieler DET nk
# Büsche NOUN ag
# . PUNCT punct
#
#  SPACE dep
# -----------------------------------
# Mehrere Männer mit Schutzhelmen bedienen ein Antriebsradsystem.
#
# Mehrere DET nk
# Männer NOUN sb
# mit ADP mnr
# Schutzhelmen NOUN nk
# bedienen VERB ROOT
# ein DET nk
# Antriebsradsystem NOUN oa
# . PUNCT punct
#
#  SPACE dep
# -----------------------------------
# Ein kleines Mädchen klettert in ein Spielhaus aus Holz.
#
# Ein DET nk
# kleines ADJ nk
# Mädchen NOUN sb
# klettert VERB ROOT
# in ADP mo
# ein DET nk
# Spielhaus NOUN nk
# aus ADP mnr
# Holz NOUN nk
# . PUNCT punct
#
#  SPACE dep
# -----------------------------------
# Ein Mann in einem blauen Hemd steht auf einer Leiter und putzt ein Fenster.
#
# Ein DET nk
# Mann NOUN sb
# in ADP mnr
# einem DET nk
# blauen ADJ nk
# Hemd NOUN nk
# steht VERB ROOT
# auf ADP mo
# einer DET nk
# Leiter NOUN nk
# und CCONJ cd
# putzt VERB cj
# ein DET nk
# Fenster NOUN oa
# . PUNCT punct
#
#  SPACE dep
# -----------------------------------
# Zwei Männer stehen am Herd und bereiten Essen zu.
#
# Zwei NUM nk
# Männer NOUN sb
# stehen VERB ROOT
# am ADP mo
# Herd NOUN nk
# und CCONJ cd
# bereiten VERB cj
# Essen PROPN oa
# zu ADP svp
# . PUNCT punct
#
#  SPACE dep

# %%
# the traial for tokenize of German
nlp_en = spacy.load('en_core_web_sm')
for text in multi30.datasets['texts_tgt_en_train'][:5]:
    print('-----------------------------------')
    print(text)
    doc = nlp_de(text)
    for token in doc:
        print(token.text, token.pos_, token.dep_)
# Out:
# -----------------------------------
# Two young, White males are outside near many bushes.
#
# Two PROPN pnc
# young PROPN ROOT
# , PUNCT punct
# White PROPN pnc
# males X cj
# are X cj
# outside X oa
# near NOUN oa
# many PROPN ag
# bushes PRON ag
# . PUNCT punct
#
#  SPACE dep
# -----------------------------------
# Several men in hard hats are operating a giant pulley system.
#
# Several NOUN ROOT
# men ADP mo
# in ADP ROOT
# hard PROPN pnc
# hats PROPN nk
# are X nk
# operating X nk
# a X uc
# giant ADV uc
# pulley PROPN pnc
# system NOUN nk
# . PUNCT punct
#
#  SPACE dep
# -----------------------------------
# A little girl climbing into a wooden playhouse.
#
# A X sb
# little X ROOT
# girl PROPN punct
# climbing PROPN pnc
# into PROPN pnc
# a PROPN pnc
# wooden ADJ nk
# playhouse NOUN ROOT
# . PUNCT punct
#
#  SPACE dep
# -----------------------------------
# A man in a blue shirt is standing on a ladder cleaning a window.
#
# A X pnc
# man PRON sb
# in ADP mo
# a PROPN pnc
# blue PROPN nk
# shirt X oa
# is X uc
# standing X uc
# on X uc
# a X pnc
# ladder X pnc
# cleaning PROPN pnc
# a PROPN pnc
# window PROPN ROOT
# . PUNCT punct
#
#  SPACE dep
# -----------------------------------
# Two men are at the stove preparing food.
#
# Two X mo
# men ADP ROOT
# are X mo
# at X uc
# the X uc
# stove X uc
# preparing X pnc
# food X nk
# . PUNCT punct
#
#  SPACE dep

# %%
from collections import Counter
